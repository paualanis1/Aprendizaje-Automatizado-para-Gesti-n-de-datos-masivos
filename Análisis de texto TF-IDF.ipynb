# %%
import nltk
nltk.download('punkt')

from textblob import TextBlob

# Lista de textos a analizar
texts = [
    "The ceremony that you do was the best!.",
    "The most original event I've seen.",
    "What a magnificient opening ceremony.",
    "Well done Paris, you are amazing!.",
    "So magic, love it, Paris is city of love.",
    "The creativity and magic of that Olympic flame is unmatched.",
    "For a moment I thought it was going to land in the Eiffel Tower.",
    "Wonderful Paris!",
    "There was no need to insult the Christian faith.",
    "At best, the opening ceremony was an embarassment at worst an insult to the history of the Olympics.",
]

# Función para obtener el sentimiento
def get_sentiment(text):
    analysis = TextBlob(text)
    # Devuelve el sentimiento con polaridad y subjetividad
    return analysis.sentiment

# Analizar los textos
for text in texts:
    sentiment = get_sentiment(text)
    print(f'Text: "{text}"')
    print(f'Polarity: {sentiment.polarity}, Subjectivity: {sentiment.subjectivity}')
    print()
# Out:
# Text: "The ceremony that you do was the best!."
# Polarity: 1.0, Subjectivity: 0.3
#
# Text: "The most original event I've seen."
# Polarity: 0.4375, Subjectivity: 0.625
#
# Text: "What a magnificient opening ceremony."
# Polarity: 0.0, Subjectivity: 0.0
#
# Text: "Well done Paris, you are amazing!."
# Polarity: 0.7500000000000001, Subjectivity: 0.9
#
# Text: "So magic, love it, Paris is city of love."
# Polarity: 0.5, Subjectivity: 0.7333333333333334
#
# Text: "The creativity and magic of that Olympic flame is unmatched."
# Polarity: 0.5, Subjectivity: 1.0
#
# Text: "For a moment I thought it was going to land in the Eiffel Tower."
# Polarity: 0.0, Subjectivity: 0.0
#
# Text: "Wonderful Paris!"
# Polarity: 1.0, Subjectivity: 1.0
#
# Text: "There was no need to insult the Christian faith."
# Polarity: 0.0, Subjectivity: 0.0
#
# Text: "At best, the opening ceremony was an embarassment at worst an insult to the history of the Olympics."
# Polarity: 0.0, Subjectivity: 0.65
# ...
